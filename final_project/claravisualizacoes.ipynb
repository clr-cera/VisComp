# %%
import polars as pl
import plotly.express as px
import pyarrow as pa

# %%
students = pl.read_csv("../data/students.csv")
grades = pl.read_csv("../data/final_table.csv")
grades = grades.with_columns(
    pl.col('Sigla').str.slice(0, 3)
    .alias('Departament'),
    pl.col('student_id').alias('IdEstudante')
    )
grades_with_students = grades.join(students, on='IdEstudante', how='left')
grades_with_students
# Out:
# shape: (224, 20)
# ┌─────────┬────────────────┬──────────────┬─────┬───┬────────────────┬───────────────┬──────┬──────┐
# │ Sigla   ┆ Nome           ┆ Ano/Semestre ┆ AU  ┆ … ┆  Classificacao ┆  AnoConclusao ┆  AAC ┆  AEX │
# │ ---     ┆ ---            ┆ ---          ┆ --- ┆   ┆ ---            ┆ ---           ┆ ---  ┆ ---  │
# │ str     ┆ str            ┆ str          ┆ i64 ┆   ┆ i64            ┆ i64           ┆ i64  ┆ i64  │
# ╞═════════╪════════════════╪══════════════╪═════╪═══╪════════════════╪═══════════════╪══════╪══════╡
# │ SCC0200 ┆ Informação     ┆ 2023/1       ┆ 2   ┆ … ┆ 16             ┆ 2027          ┆ 80   ┆ 190  │
# │         ┆ Profissional e ┆              ┆     ┆   ┆                ┆               ┆      ┆      │
# │         ┆ Tuto…          ┆              ┆     ┆   ┆                ┆               ┆      ┆      │
# │ SCC0221 ┆ Introdução à   ┆ 2023/1       ┆ 4   ┆ … ┆ 16             ┆ 2027          ┆ 80   ┆ 190  │
# │         ┆ Ciência de     ┆              ┆     ┆   ┆                ┆               ┆      ┆      │
# │         ┆ Comput…        ┆              ┆     ┆   ┆                ┆               ┆      ┆      │
# │ SCC0222 ┆ Laboratório de ┆ 2023/1       ┆ 2   ┆ … ┆ 16             ┆ 2027          ┆ 80   ┆ 190  │
# │         ┆ Introdução à   ┆              ┆     ┆   ┆                ┆               ┆      ┆      │
# │         ┆ Ci…            ┆              ┆     ┆   ┆                ┆               ┆      ┆      │
# │ SMA0300 ┆ Geometria      ┆ 2023/1       ┆ 4   ┆ … ┆ 16             ┆ 2027          ┆ 80   ┆ 190  │
# │         ┆ Analítica      ┆              ┆     ┆   ┆                ┆               ┆      ┆      │
# │ SMA0353 ┆ Cálculo I      ┆ 2023/1       ┆ 4   ┆ … ┆ 16             ┆ 2027          ┆ 80   ┆ 190  │
# │ …       ┆ …              ┆ …            ┆ …   ┆ … ┆ …              ┆ …             ┆ …    ┆ …    │
# │ SME0104 ┆ Cálculo        ┆ 2025/1       ┆ 4   ┆ … ┆ 32             ┆ 2027          ┆ 1    ┆ 180  │
# │         ┆ Numérico       ┆              ┆     ┆   ┆                ┆               ┆      ┆      │
# │ SME0121 ┆ Processos      ┆ 2025/1       ┆ 4   ┆ … ┆ 32             ┆ 2027          ┆ 1    ┆ 180  │
# │         ┆ Estocásticos   ┆              ┆     ┆   ┆                ┆               ┆      ┆      │
# │ SME0130 ┆ Redes          ┆ 2025/1       ┆ 4   ┆ … ┆ 32             ┆ 2027          ┆ 1    ┆ 180  │
# │         ┆ Complexas      ┆              ┆     ┆   ┆                ┆               ┆      ┆      │
# │ SSC0130 ┆ Engenharia de  ┆ 2025/1       ┆ 4   ┆ … ┆ 32             ┆ 2027          ┆ 1    ┆ 180  │
# │         ┆ Software       ┆              ┆     ┆   ┆                ┆               ┆      ┆      │
# │ SSC0142 ┆ Redes de       ┆ 2025/1       ┆ 4   ┆ … ┆ 32             ┆ 2027          ┆ 1    ┆ 180  │
# │         ┆ Computadores   ┆              ┆     ┆   ┆                ┆               ┆      ┆      │
# └─────────┴────────────────┴──────────────┴─────┴───┴────────────────┴───────────────┴──────┴──────┘

# %%
# plot grade average per department

dept_avg = grades_with_students.group_by('Departament').agg(pl.col('NOTA').mean())
plot = px.bar(dept_avg.to_pandas(), x='Departament', y='NOTA', title='Average Grade per Department', color='Departament')
plot.show()

# %%
# Grades per semester

grades_with_rel_semester = grades_with_students.with_columns(
    pl.col('Ano/Semestre').str.split('/').list.get(0).cast(pl.Int32).alias('Ano'),
    pl.col('Ano/Semestre').str.split('/').list.get(1).cast(pl.Int32).alias('Semestre')
    ).with_columns(
        ((pl.col('Ano')-pl.col('AnoIngresso'))*2 + pl.col('Semestre')).alias('RelSemester')
        )

grades_with_rel_semester
# Out:
# shape: (224, 23)
# ┌─────────┬────────────────────────┬──────────────┬─────┬───┬──────┬──────┬──────────┬─────────────┐
# │ Sigla   ┆ Nome                   ┆ Ano/Semestre ┆ AU  ┆ … ┆  AEX ┆ Ano  ┆ Semestre ┆ RelSemester │
# │ ---     ┆ ---                    ┆ ---          ┆ --- ┆   ┆ ---  ┆ ---  ┆ ---      ┆ ---         │
# │ str     ┆ str                    ┆ str          ┆ i64 ┆   ┆ i64  ┆ i32  ┆ i32      ┆ i64         │
# ╞═════════╪════════════════════════╪══════════════╪═════╪═══╪══════╪══════╪══════════╪═════════════╡
# │ SCC0200 ┆ Informação             ┆ 2023/1       ┆ 2   ┆ … ┆ 190  ┆ 2023 ┆ 1        ┆ 1           │
# │         ┆ Profissional e Tuto…   ┆              ┆     ┆   ┆      ┆      ┆          ┆             │
# │ SCC0221 ┆ Introdução à Ciência   ┆ 2023/1       ┆ 4   ┆ … ┆ 190  ┆ 2023 ┆ 1        ┆ 1           │
# │         ┆ de Comput…             ┆              ┆     ┆   ┆      ┆      ┆          ┆             │
# │ SCC0222 ┆ Laboratório de         ┆ 2023/1       ┆ 2   ┆ … ┆ 190  ┆ 2023 ┆ 1        ┆ 1           │
# │         ┆ Introdução à Ci…       ┆              ┆     ┆   ┆      ┆      ┆          ┆             │
# │ SMA0300 ┆ Geometria Analítica    ┆ 2023/1       ┆ 4   ┆ … ┆ 190  ┆ 2023 ┆ 1        ┆ 1           │
# │ SMA0353 ┆ Cálculo I              ┆ 2023/1       ┆ 4   ┆ … ┆ 190  ┆ 2023 ┆ 1        ┆ 1           │
# │ …       ┆ …                      ┆ …            ┆ …   ┆ … ┆ …    ┆ …    ┆ …        ┆ …           │
# │ SME0104 ┆ Cálculo Numérico       ┆ 2025/1       ┆ 4   ┆ … ┆ 180  ┆ 2025 ┆ 1        ┆ 5           │
# │ SME0121 ┆ Processos Estocásticos ┆ 2025/1       ┆ 4   ┆ … ┆ 180  ┆ 2025 ┆ 1        ┆ 5           │
# │ SME0130 ┆ Redes Complexas        ┆ 2025/1       ┆ 4   ┆ … ┆ 180  ┆ 2025 ┆ 1        ┆ 5           │
# │ SSC0130 ┆ Engenharia de Software ┆ 2025/1       ┆ 4   ┆ … ┆ 180  ┆ 2025 ┆ 1        ┆ 5           │
# │ SSC0142 ┆ Redes de Computadores  ┆ 2025/1       ┆ 4   ┆ … ┆ 180  ┆ 2025 ┆ 1        ┆ 5           │
# └─────────┴────────────────────────┴──────────────┴─────┴───┴──────┴──────┴──────────┴─────────────┘

# %%
# Plot grade average per relative semester with plotly

average_grades_per_semester = grades_with_rel_semester.group_by('RelSemester').agg(
    pl.col('NOTA').mean().alias('AverageGrade')
    ).sort('RelSemester')

fig = px.line(average_grades_per_semester.filter(pl.col('RelSemester') < 6), x='RelSemester', y='AverageGrade', title='Média das Notas por Semestre Relativo')
fig.update_xaxes(dtick=1)
fig.show()

# %%
# sum AU per semester with plotly

# plot average AU sum per student per relative semester
au_per_student_semester = grades_with_rel_semester.group_by(['IdEstudante', 'RelSemester']).agg(
    pl.col('AU').sum().alias('TotalAU')
    )

au_per_student_semester.sort(['IdEstudante', 'RelSemester'])
# Out:
# shape: (31, 3)
# ┌─────────────┬─────────────┬─────────┐
# │ IdEstudante ┆ RelSemester ┆ TotalAU │
# │ ---         ┆ ---         ┆ ---     │
# │ i64         ┆ i64         ┆ i64     │
# ╞═════════════╪═════════════╪═════════╡
# │ 0           ┆ 1           ┆ 24      │
# │ 0           ┆ 2           ┆ 28      │
# │ 0           ┆ 3           ┆ 19      │
# │ 0           ┆ 4           ┆ 17      │
# │ 0           ┆ 5           ┆ 24      │
# │ …           ┆ …           ┆ …       │
# │ 4           ┆ 1           ┆ 24      │
# │ 4           ┆ 2           ┆ 28      │
# │ 4           ┆ 3           ┆ 21      │
# │ 4           ┆ 4           ┆ 31      │
# │ 4           ┆ 5           ┆ 30      │
# └─────────────┴─────────────┴─────────┘

# %%
average_au_per_semester = au_per_student_semester.group_by('RelSemester').agg(
    pl.col('TotalAU').mean().alias('AverageAU')
    ).sort('RelSemester')
fig2 = px.line(average_au_per_semester.filter(pl.col('RelSemester') < 6), x='RelSemester', y='AverageAU', title='Média de AU por Semestre Relativo')
fig2.update_xaxes(dtick=1)
fig2.show()

# %%
# plot names per frequency average, to identify lesson names with low frequency
name_frequency = grades_with_rel_semester.filter(pl.col('RelSemester') < 6).group_by('Nome').agg(
    pl.col('FREQ').mean().alias('AverageFrequency'))
name_frequency_sorted = name_frequency.sort('AverageFrequency')
name_frequency_sorted
# Out:
# shape: (46, 2)
# ┌─────────────────────────────────┬──────────────────┐
# │ Nome                            ┆ AverageFrequency │
# │ ---                             ┆ ---              │
# │ str                             ┆ f64              │
# ╞═════════════════════════════════╪══════════════════╡
# │ Cálculo IV                      ┆ 70.0             │
# │ Redes de Computadores           ┆ 74.0             │
# │ Introdução ao Desenvolvimento … ┆ 74.8             │
# │ Prática em Organização de Comp… ┆ 76.0             │
# │ Análise e Projeto Orientados a… ┆ 76.6             │
# │ …                               ┆ …                │
# │ Laboratório de Introdução à Ci… ┆ 100.0            │
# │ Tópicos Avançados em Ciências … ┆ 100.0            │
# │ Cálculo I                       ┆ 100.0            │
# │ Programação Funcional           ┆ 100.0            │
# │ Introdução à Bioinformática     ┆ 100.0            │
# └─────────────────────────────────┴──────────────────┘

# %%
fig3 = px.bar(name_frequency_sorted.head(10).to_pandas(), x='AverageFrequency', y='Nome', title='Top 10 Disciplinas com Menor Frequência', color='AverageFrequency', orientation='h')
fig3.show()

# %%
# Grades scatter plot per AU+TR

fig4 = px.scatter(grades_with_rel_semester.filter(pl.col('RelSemester') < 6).to_pandas(), x='AU+TR', y='NOTA', title='Dispersão de Notas por AU e TR')
fig4.show()

# %%
# Count departament occurrences per student
dept_counts = grades_with_students.group_by(['IdEstudante', 'Departament']).agg(
    pl.len().alias('Count')
    ).sort(['IdEstudante', 'Count'])
dept_counts
# Out:
# shape: (25, 3)
# ┌─────────────┬─────────────┬───────┐
# │ IdEstudante ┆ Departament ┆ Count │
# │ ---         ┆ ---         ┆ ---   │
# │ i64         ┆ str         ┆ u32   │
# ╞═════════════╪═════════════╪═══════╡
# │ 0           ┆ 760         ┆ 2     │
# │ 0           ┆ SME         ┆ 4     │
# │ 0           ┆ SMA         ┆ 5     │
# │ 0           ┆ SCC         ┆ 12    │
# │ 0           ┆ SSC         ┆ 13    │
# │ …           ┆ …           ┆ …     │
# │ 4           ┆ 760         ┆ 2     │
# │ 4           ┆ SME         ┆ 5     │
# │ 4           ┆ SMA         ┆ 6     │
# │ 4           ┆ SCC         ┆ 14    │
# │ 4           ┆ SSC         ┆ 16    │
# └─────────────┴─────────────┴───────┘

# %%
# Plot departament count per student
fig5 = px.bar(dept_counts.to_pandas(), x='IdEstudante', y='Count', color='Departament', title='Contagem de Departamentos por Estudante', barmode='group', orientation='v')
fig5.show()

# %%
# Sum EXT per student
ext_per_student = grades_with_students.group_by('IdEstudante').agg(
    pl.col('EXT').sum().alias('TotalEXT')
    ).sort('TotalEXT')
ext_per_student
# Out:
# shape: (5, 2)
# ┌─────────────┬──────────┐
# │ IdEstudante ┆ TotalEXT │
# │ ---         ┆ ---      │
# │ i64         ┆ i64      │
# ╞═════════════╪══════════╡
# │ 2           ┆ 0        │
# │ 1           ┆ 170      │
# │ 4           ┆ 180      │
# │ 3           ┆ 2575     │
# │ 0           ┆ 2640     │
# └─────────────┴──────────┘

# %%
import pandas
dependencies_df = pandas.read_csv('../data/dependencies.csv')
dependencies_df
# Out:
#                                                Subject     Code  \
# 0    Informação Profissional e Tutoria Acadêmica em...  SCC0200
# 1                 Introdução à Ciência de Computação I  SCC0221
# 2    Laboratório de Introdução à Ciência de Computa...  SCC0222
# 3                                  Geometria Analítica  SMA0300
# 4                                            Cálculo I  SMA0353
# ..                                                 ...      ...
# 131                             Projeto Empreendedor I  SCC0300
# 132                     Mineração Estatística de Dados  SME0878
# 133                          Projeto em Intercâmbio II  SCC0290
# 134                            Projeto de Graduação II  SCC0294
# 135                            Projeto Empreendedor II  SCC0302
#
#                                Type            Semester  \
# 0          Disciplinas Obrigatórias   1º Semestre Ideal
# 1          Disciplinas Obrigatórias   1º Semestre Ideal
# 2          Disciplinas Obrigatórias   1º Semestre Ideal
# 3          Disciplinas Obrigatórias   1º Semestre Ideal
# 4          Disciplinas Obrigatórias   1º Semestre Ideal
# ..                              ...                 ...
# 131  Disciplinas Optativas Eletivas   9º Semestre Ideal
# 132  Disciplinas Optativas Eletivas   9º Semestre Ideal
# 133  Disciplinas Optativas Eletivas  10º Semestre Ideal
# 134  Disciplinas Optativas Eletivas  10º Semestre Ideal
# 135  Disciplinas Optativas Eletivas  10º Semestre Ideal
#
#                  RequirementOf  \
# 0                          NaN
# 1                      SCC0201
# 2                          NaN
# 3                      SMA0394
# 4    7600105; SMA0354; SMA0392
# ..                         ...
# 131                        NaN
# 132                        NaN
# 133                        NaN
# 134                        NaN
# 135                        NaN
#
#                                                   Goal  \
# 0    Ambientar o estudante com o curso de Bacharela...
# 1    Apresentar os conceitos básicos para o desenvo...
# 2    Implementar em laboratório as técnicas de prog...
# 3    Visa familiarizar os alunos com a geometria an...
# 4    Fazer com que os alunos familiarizem-se com os...
# ..                                                 ...
# 131  Permitir que o aluno demonstre capacidade empr...
# 132  Apresentar ao aluno os principais conceitos e ...
# 133  O objetivo desta disciplina é o de permitir ao...
# 134  Para os alunos que optarem por projeto de grad...
# 135  Permitir que o aluno demonstre capacidade empr...
#
#                                                  About
# 0    Disciplina de caráter informativo, oferecendo ...
# 1    Conceitos básicos sobre computadores: hardware...
# 2    Resolução de problemas e desenvolvimento de pr...
# 3    Coordenadas cartesianas.  Vetores. Dependência...
# 4    O conjunto dos números reais. Funções Reais de...
# ..                                                 ...
# 131  Descrição de projeto desenvolvido ou de um tex...
# 132  Introdução à mineração de dados. Mineração de ...
# 133  Para os alunos que optarem por um estágio em u...
# 134  Para os alunos que optarem por projeto de grad...
# 135  Descrição de projeto desenvolvido ou de um tex...
#
# [136 rows x 7 columns]

# %%
# transform dataframe to edge list
edge_list = pandas.DataFrame(columns=['source', 'target','weight'])

for index, row in dependencies_df.iterrows():
    source = row['Code'].strip()
    if pandas.isna(row['RequirementOf']):
        edge_list.loc[len(edge_list)] = {'source': source, 'target': source, 'weight': 0}
        continue
    target_list = row['RequirementOf'].split(';')
    for target in target_list:
        target = target.strip()
        weight = 1
        edge_list.loc[len(edge_list)] = {'source': source, 'target': target, 'weight': weight}

# %%
edge_list
# Out:
#       source   target  weight
# 0    SCC0200  SCC0200       0
# 1    SCC0221  SCC0201       1
# 2    SCC0222  SCC0222       0
# 3    SMA0300  SMA0394       1
# 4    SMA0353  7600105       1
# ..       ...      ...     ...
# 204  SCC0300  SCC0300       0
# 205  SME0878  SME0878       0
# 206  SCC0290  SCC0290       0
# 207  SCC0294  SCC0294       0
# 208  SCC0302  SCC0302       0
#
# [209 rows x 3 columns]

# %%
edge_list.to_csv('../data/dependencies_edge_list.csv', index=False)

# %%
import networkx as nx
import matplotlib.pyplot as plt
import plotly.graph_objects as go
G = nx.from_pandas_edgelist(edge_list, 'source', 'target', ['weight'])
plt.figure(figsize=(12, 12))
pos = nx.spring_layout(G, k=0.15, iterations=35)
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None) # Separates segments
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

node_x = []
node_y = []
node_text = [] # For hover information
for node in G.nodes():
    x, y = pos[node]
    node_x.append(x)
    node_y.append(y)
    # Get hover text information from dependencies_df
    hover_info = dependencies_df[dependencies_df['Code'] == node]
    hover_text = f"Código: {node}<br>"
    if not hover_info.empty:
        hover_text += f"Nome: {hover_info.iloc[0]['Subject']}<br>"
        hover_text += f"Tipo: {hover_info.iloc[0]['Type']}<br>"
        hover_text += f"Objetivo: {hover_info.iloc[0]['Goal']}<br>"
    node_text.append(hover_text)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    text=node_text,
    marker=dict(
        showscale=False,
        size=10,
        color='skyblue',
        line_width=2))

# %%
fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='Grafo de Dependência de Disciplinas',
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=20,l=5,r=5,t=40),
                    xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                    yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                )
fig.show()
